# %%
# %run ./main
# Out:
# ...
# 100%|██████████| 30/30 [00:00<00:00, 39.19it/s]
# Number of kcore selected playlists: 12322
# Number of kcore selected tracks: 7669
# Number of kcore selected nodes: 19991
# Number of kcore selected edges: 832153
# Train set has 294269 positive supervision edges
# Validation set has 63057 positive supervision edges
# Test set has 63057 positive supervision edges
# Train set has 588538 message passing edges
# Validation set has 588538 message passing edges
# Test set has 714652 message passing edges
# Number of kcore selected artists: 2119
# Beginning training for LGCN_CHEB_3_e64_nodes22110_ w artist nodes
# Epoch 0; Train loss 0.6935838460922241; Val loss 0.6852668523788452; Train ROC 0.5026103888332075; Val ROC 0.7358957136330345
# Val recall 0.3738069534301758
# Epoch 1; Train loss 0.6849572658538818; Val loss 0.5280694365501404; Train ROC 0.7460735750342418; Val ROC 0.738417352936063
# ...

# %%
# %run ./main
# Out:
# ...
# 100%|██████████| 30/30 [00:00<00:00, 34.18it/s]
# Number of kcore selected playlists: 12322
# Number of kcore selected tracks: 7669
# Number of kcore selected nodes: 19991
# Number of kcore selected edges: 832153
# Train set has 294269 positive supervision edges
# Validation set has 63057 positive supervision edges
# Test set has 63057 positive supervision edges
# Train set has 588538 message passing edges
# Validation set has 588538 message passing edges
# Test set has 714652 message passing edges
# Number of kcore selected artists: 2119
# Beginning training for LGCN_SAGE_3_e64_nodes22110_ w artist nodes
# Epoch 0; Train loss 0.6926957368850708; Val loss 0.6763220429420471; Train ROC 0.5133407951131713; Val ROC 0.739348591451907
# Val recall 0.29429754614830017
# Epoch 1; Train loss 0.6758726239204407; Val loss 0.5861930847167969; Train ROC 0.7428910417188507; Val ROC 0.7363647186801382
# ...

# %%
# %run ./main
# Out:
# ...
# 100%|██████████| 30/30 [00:00<00:00, 38.31it/s]
# Number of kcore selected playlists: 12322
# Number of kcore selected tracks: 7669
# Number of kcore selected nodes: 19991
# Number of kcore selected edges: 832153
# Train set has 294269 positive supervision edges
# Validation set has 63057 positive supervision edges
# Test set has 63057 positive supervision edges
# Train set has 588538 message passing edges
# Validation set has 588538 message passing edges
# Test set has 714652 message passing edges
# Number of kcore selected artists: 2119
# Beginning training for LGCN_LGC_3_e64_nodes22110_ w artist nodes
# Epoch 0; Train loss 0.6931569576263428; Val loss 0.6931402683258057; Train ROC 0.61978674831386; Val ROC 0.7287484681526718
# Val recall 0.31568536162376404
# Epoch 1; Train loss 0.6931374073028564; Val loss 0.6930071711540222; Train ROC 0.8183002394713857; Val ROC 0.7942191538344998
# ...
