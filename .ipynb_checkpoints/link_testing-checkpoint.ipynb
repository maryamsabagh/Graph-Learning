# %%
import torch
import numpy as np
import networkx as nx
from torch_geometric.data import Data
from torch_geometric.transforms import RandomLinkSplit
from torch_geometric.utils import to_undirected

edge_list = [
    (1, 2), (1, 4), (5, 8), (7, 4),
    (9, 2), (7, 8), (5, 2), (3, 6),
    (7, 2), (9, 4)
]

# Step 2: Create undirected graph
num_nodes = 10 
G = nx.Graph()
G.add_edges_from(edge_list)

coo_graph = np.array(G.edges()).T  # shape: [2, num_edges]
num_nodes = G.number_of_nodes()

# Step 3: Create PyG Data object
edge_idx = torch.tensor(coo_graph, dtype=torch.long)
graph_data = Data(edge_index=edge_idx, num_nodes=num_nodes)


transform = RandomLinkSplit(
    is_undirected=True,
    add_negative_train_samples=False,
    neg_sampling_ratio=0.0,
    num_val=0.2,
    num_test=0.2
)
train_data, val_data, test_data = transform(graph_data)



# Example: G_M and G_S usage in training
print("TRAIN mp:", train_data.edge_index)
print("TRAIN super:", train_data.edge_label_index)
print("VAL mp:", val_data.edge_index)
print("VAL super:", val_data.edge_label_index)
print("TEST mp:", test_data.edge_index)
print("TEST super:",test_data.edge_label_index)
# Out:
# TRAIN mp: tensor([[3, 2, 4, 4, 1, 5, 2, 6, 7, 9, 7, 2, 8, 5],
#         [6, 7, 9, 7, 2, 8, 5, 3, 2, 4, 4, 1, 5, 2]])
# TRAIN super: tensor([[3, 2, 4, 4, 1, 5, 2],
#         [6, 7, 9, 7, 2, 8, 5]])
# VAL mp: tensor([[3, 2, 4, 4, 1, 5, 2, 6, 7, 9, 7, 2, 8, 5],
#         [6, 7, 9, 7, 2, 8, 5, 3, 2, 4, 4, 1, 5, 2]])
# VAL super: tensor([[2],
#         [9]])
# TEST mp: tensor([[3, 2, 4, 4, 1, 5, 2, 2, 6, 7, 9, 7, 2, 8, 5, 9],
#         [6, 7, 9, 7, 2, 8, 5, 9, 3, 2, 4, 4, 1, 5, 2, 2]])
# TEST super: tensor([[1],
#         [4]])
