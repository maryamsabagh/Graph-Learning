# %%
import pickle
import os
from recall_loss_auc import *

import matplotlib
plt.rcParams.update({ "text.usetex": True, "font.family": "serif" })
font = {'size': 14}
matplotlib.rc('font', **font)
fmt = 'pdf'

# %%
MAIN_DIR='/home/jovyan/code4/spotify_analysis/model_stats'
os.chdir(MAIN_DIR)

one_neg_dirc= MAIN_DIR+'/1_neg/reg'
ten_neg_dirc= MAIN_DIR+'/10_neg/reg'
ten_neg_w_art= MAIN_DIR+'/10_neg'

# %%
os.chdir(one_neg_dirc)

# %%
cheb_w_1 = load_model_runs("CHEB",1)
sage_w_1 = load_model_runs("SAGE",1)
lgcn_w_1 = load_model_runs("LGC",1)

mean_recall_cheb_1, std_recall_cheb_1 = compute_recall(cheb_w_1)
mean_recall_sage_1, std_recall_sage_1 = compute_recall(sage_w_1)
mean_recall_lgcn_1, std_recall_lgcn_1 = compute_recall(lgcn_w_1)

mean_loss_cheb_1, std_loss_cheb_1 = compute_loss(cheb_w_1)
mean_loss_sage_1, std_loss_sage_1 = compute_loss(sage_w_1)
mean_loss_lgcn_1, std_loss_lgcn_1 = compute_loss(lgcn_w_1)

mean_auc_cheb_1, std_auc_cheb_1 = compute_AUC(cheb_w_1)
mean_auc_sage_1, std_auc_sage_1 = compute_AUC(sage_w_1)
mean_auc_lgcn_1, std_auc_lgcn_1 = compute_AUC(lgcn_w_1)
# Out:
# /opt/conda/lib/python3.11/site-packages/torch/storage.py:414: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(io.BytesIO(b))

# %%
plt.figure()
plot(mean_recall_sage_1, std_recall_sage_1, label="SAGE", color='b')
plot(mean_recall_cheb_1, std_recall_cheb_1, label="CHEB", color='r')
plot(mean_recall_lgcn_1, std_recall_lgcn_1, label="LGCN", color='g')
plt.ylim(0.1,0.7)
plt.legend()
plt.title("Spotify Data: Recall@300, 1 Negative Edge")
plt.xlabel("Epochs")
plt.ylabel("Recall")
plt.savefig("1_neg_recall.pdf", dpi=150, bbox_inches='tight')

# %%
plt.figure()
plot(mean_loss_sage_1, std_loss_sage_1, label="SAGE", color='b')
plot(mean_loss_cheb_1, std_loss_cheb_1, label="CHEB", color='r')
plot(mean_loss_lgcn_1, std_loss_lgcn_1, label="LGCN", color='g')
plt.ylim(0.1,0.7)
plt.legend()
plt.title("Spotify Data: Loss, 1 Negative Edge")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.savefig("1_neg_loss.pdf", dpi=150, bbox_inches='tight')

# %%
plt.figure()
plot(mean_auc_sage_1, std_auc_sage_1, label="SAGE", color='b')
plot(mean_auc_cheb_1, std_auc_cheb_1, label="CHEB", color='r')
plot(mean_auc_lgcn_1, std_auc_lgcn_1, label="LGCN", color='g')
plt.legend()
plt.title("Spotify Data: AUC, 1 Negative Edge")
plt.xlabel("Epochs")
plt.ylabel("AUC")
plt.savefig("1_neg_auc.pdf", dpi=150, bbox_inches='tight')

# %%
os.chdir(ten_neg_dirc)

# %%
cheb_w_10 = load_model_runs("CHEB",10)
sage_w_10 = load_model_runs("SAGE",10)
lgcn_w_10 = load_model_runs("LGC",10)

mean_recall_cheb_10, std_recall_cheb_10 = compute_recall(cheb_w_10)
mean_recall_sage_10, std_recall_sage_10 = compute_recall(sage_w_10)
mean_recall_lgcn_10, std_recall_lgcn_10 = compute_recall(lgcn_w_10)

mean_loss_cheb_10, std_loss_cheb_10 = compute_loss(cheb_w_10)
mean_loss_sage_10, std_loss_sage_10 = compute_loss(sage_w_10)
mean_loss_lgcn_10, std_loss_lgcn_10 = compute_loss(lgcn_w_10)

mean_auc_cheb_10, std_auc_cheb_10 = compute_AUC(cheb_w_10)
mean_auc_sage_10, std_auc_sage_10 = compute_AUC(sage_w_10)
mean_auc_lgcn_10, std_auc_lgcn_10 = compute_AUC(lgcn_w_10)
# Out:
# /opt/conda/lib/python3.11/site-packages/torch/storage.py:414: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(io.BytesIO(b))

# %%
plt.figure()
plot(mean_recall_sage_10, std_recall_sage_10, label="SAGE", color='b')
plot(mean_recall_cheb_10, std_recall_cheb_10, label="CHEB", color='r')
plot(mean_recall_lgcn_10, std_recall_lgcn_10, label="LGCN", color='g')
plt.ylim(0.1,0.7)
plt.legend()
plt.title("Spotify Data: Recall@300, 10 Negative Edges")
plt.xlabel("Epochs")
plt.ylabel("Recall")
plt.savefig("10_neg_recall.pdf", dpi=150, bbox_inches='tight')

# %%
plt.figure()
plot(mean_loss_sage_10, std_loss_sage_10, label="SAGE", color='b')
plot(mean_loss_cheb_10, std_loss_cheb_10, label="CHEB", color='r')
plot(mean_loss_lgcn_10, std_loss_lgcn_10, label="LGCN", color='g')
plt.ylim(0.1,0.7)
plt.legend()
plt.title("Spotify Data: Loss, 10 Negative Edges")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.savefig("10_neg_loss.pdf", dpi=150, bbox_inches='tight')

# %%
plt.figure()
plot(mean_auc_sage_10, std_auc_sage_10, label="SAGE", color='b')
plot(mean_auc_cheb_10, std_auc_cheb_10, label="CHEB", color='r')
plot(mean_auc_lgcn_10, std_auc_lgcn_10, label="LGCN", color='g')
plt.legend()
plt.title("Spotify Data: AUC, 10 Negative Edges")
plt.xlabel("Epochs")
plt.ylabel("AUC")
plt.savefig("10_neg_auc.pdf", dpi=150, bbox_inches='tight')

# %%
os.chdir(ten_neg_w_art)

# %%
art_cheb_w_10 = load_model_runs("CHEB",10,art=True)
art_sage_w_10 = load_model_runs("SAGE",10,art=True)
art_lgcn_w_10 = load_model_runs("LGC",10,art=True)

art_mean_recall_cheb_10, art_std_recall_cheb_10 = compute_recall(art_cheb_w_10)
art_mean_recall_sage_10, art_std_recall_sage_10 = compute_recall(art_sage_w_10)
art_mean_recall_lgcn_10, art_std_recall_lgcn_10 = compute_recall(art_lgcn_w_10)

art_mean_loss_cheb_10, art_std_loss_cheb_10 = compute_loss(art_cheb_w_10)
art_mean_loss_sage_10, art_std_loss_sage_10 = compute_loss(art_sage_w_10)
art_mean_loss_lgcn_10, art_std_loss_lgcn_10 = compute_loss(art_lgcn_w_10)

art_mean_auc_cheb_10, art_std_auc_cheb_10 = compute_AUC(art_cheb_w_10)
art_mean_auc_sage_10, art_std_auc_sage_10 = compute_AUC(art_sage_w_10)
art_mean_auc_lgcn_10, art_std_auc_lgcn_10 = compute_AUC(art_lgcn_w_10)
# Out:
# /opt/conda/lib/python3.11/site-packages/torch/storage.py:414: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(io.BytesIO(b))
# ...

# %%
plt.figure()
plot(art_mean_recall_sage_10, art_std_recall_sage_10, label="SAGE", color='b')
plot(art_mean_recall_cheb_10, art_std_recall_cheb_10, label="CHEB", color='r')
plot(art_mean_recall_lgcn_10, art_std_recall_lgcn_10, label="LGCN", color='g')
plt.ylim(0.1,0.77)
plt.legend()
plt.title("Spotify Data with Artists: Recall@300, 10 Negative Edges")
plt.xlabel("Epochs")
plt.ylabel("Recall")
plt.savefig("art_10_neg_recall.pdf", dpi=150)

# %%
plt.figure()
plot(art_mean_loss_sage_10, art_std_loss_sage_10, label="SAGE", color='b')
plot(art_mean_loss_cheb_10, art_std_loss_cheb_10, label="CHEB", color='r')
plot(art_mean_loss_lgcn_10, art_std_loss_lgcn_10, label="LGCN", color='g')
plt.ylim(0.1,0.7)
plt.legend()
plt.title("Spotify Data with Artists: Loss, 10 Negative Edges")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.savefig("art_10_neg_loss.pdf", dpi=150, bbox_inches='tight')

# %%
plt.figure()
plot(art_mean_auc_sage_10, art_std_auc_sage_10, label="SAGE", color='b')
plot(art_mean_auc_cheb_10, art_std_auc_cheb_10, label="CHEB", color='r')
plot(art_mean_auc_lgcn_10, art_std_auc_lgcn_10, label="LGCN", color='g')
plt.legend()
plt.title("Spotify Data with Artists: AUC, 10 Negative Edges")
plt.xlabel("Epochs")
plt.ylabel("AUC")
plt.savefig("art_10_neg_auc.pdf", dpi=150, bbox_inches='tight')
